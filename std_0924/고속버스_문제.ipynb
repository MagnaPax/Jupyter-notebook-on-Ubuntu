# %%
import pandas as pd

# %%
# 데이터 불러와서 상위 5개만 출력
df = pd.read_excel('dataset/고속버스.xlsx') #액셀로 된 데이터를 불러와서 데이터 프레임으로 만들기 
df.head(5)
# Out:
#    차종   선별 출발지   도착지     거리  총운행횟수  총이용인원   이용율
# 0  우등  88선  광주    울산  327.8    412   7283  63.1
# 1  고속  88선  광주    울산  327.8    145   3050  46.7
# 2  우등  88선  광주  울산신복  327.8    164    545  11.9
# 3  고속  88선  광주  울산신복  327.8     70    311   9.9
# 4  우등  88선  광주   동대구  219.3   1369  21873  57.1

# %%
# 필터링 - 우등고속에 대한 데이터대상
# 차종이 우등인 행만 출력
df[df['차종'] == '우등']
# Out:
#      차종   선별   출발지   도착지     거리  총운행횟수  총이용인원    이용율
# 0    우등  88선    광주    울산  327.8    412   7283   63.1
# 2    우등  88선    광주  울산신복  327.8    164    545   11.9
# 4    우등  88선    광주   동대구  219.3   1369  21873   57.1
# 6    우등  88선    광주    구미  246.1    208   2634   45.2
# 7    우등  88선    광주    경주  286.9    139   2102   54.0
# 8    우등  88선    광주    포항  303.2    234   3931   60.0
# 10   우등  88선    목포   동대구  295.7    131   1447   39.4
# 11   우등  88선    목포    구미  347.4    114   1732   54.3
# 12   우등  88선    전주    부산  265.1    752   9232   43.8
# 14   우등  88선    전주    울산  308.7    196   2932   53.4
# 16   우등  88선    전주   동대구  198.5    464   7521   57.9
# 21   우등  경부선  서울경부  대전복합  153.2   3555  77759   78.1
# 24   우등  경부선  서울경부    공주  125.9   1633  36623   80.1
# 26   우등  경부선  서울경부    금산  188.3    241   3507   52.0
# 30   우등  경부선  서울경부   세종시  130.7   3656  63570   62.1
# 31   우등  경부선  서울경부    청주  123.0   3705  77586   74.8
# 33   우등  경부선  서울경부    부산  384.3   2597  46336   63.7
# ...

# %%
# 필터링 - 경부선에서 총이용인원이 1000명 이상인 데이타대상
#df[df['선별'] == '경부선']
df[df[df['선별'] == '경부선']
# Out:
#      차종   선별   출발지   도착지     거리  총운행횟수   총이용인원   이용율
# 18   고속  경부선  서울경부    안성   77.8   3541   99277  62.3
# 19   고속  경부선  서울경부  안성중대   74.0   1744   29615  37.7
# 20   고속  경부선  서울경부    평택   69.8   2770   72167  57.9
# 21   우등  경부선  서울경부  대전복합  153.2   3555   77759  78.1
# 22   고속  경부선  서울경부  대전복합  153.2   1507   64208  94.7
# 23   고속  경부선  서울경부    천안   84.1   5213  185241  79.0
# 24   우등  경부선  서울경부    공주  125.9   1633   36623  80.1
# 25   고속  경부선  서울경부    공주  125.9    490   13668  62.0
# 26   우등  경부선  서울경부    금산  188.3    241    3507  52.0
# 27   고속  경부선  서울경부    금산  188.3    271    6304  51.7
# 28   고속  경부선  서울경부  아산온양  100.0   1530   41208  59.9
# 29   고속  경부선  서울경부   조치원  119.1    953   20447  47.7
# 30   우등  경부선  서울경부   세종시  130.7   3656   63570  62.1
# 31   우등  경부선  서울경부    청주  123.0   3705   77586  74.8
# 32   고속  경부선  서울경부    청주  123.0   2030   44563  48.8
# 33   우등  경부선  서울경부    부산  384.3   2597   46336  63.7
# 34   고속  경부선  서울경부    부산  384.3    663   20800  69.7
# ...
